# %%
import pandas as pd

# %%
#method 1: specify full path to file

# %%
#windows:
#stats = pd.read_csv("C:\\Users\\Kirill\\Desktop\\Pythonprogramming course")
stats=pd.read_csv("/Users/balajiMacbook/Desktop/Python Course/DemographicData.csv")

# %%
stats
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# 11                          Burundi          BDI      44.151         1.30000
# 12                          Belgium          BEL      11.200        82.17020
# 13                            Benin          BEN      36.440         4.90000
# 14                     Burkina Faso          BFA      40.551         9.10000
# 15                       Bangladesh          BGD      20.142         6.63000
# 16                         Bulgaria          BGR       9.200        53.06150
# 17                          Bahrain          BHR      15.040        90.00004
# 18                     Bahamas, The          BHS      15.339        72.00000
# 19           Bosnia and Herzegovina          BIH       9.062        57.79000
# 20                          Belarus          BLR      12.500        54.17000
# 21                           Belize          BLZ      23.092        33.60000
# 22                          Bermuda          BMU      10.400        95.30000
# 23                          Bolivia          BOL      24.236        36.94000
# 24                           Brazil          BRA      14.931        51.04000
# 25                         Barbados          BRB      12.188        73.00000
# 26                Brunei Darussalam          BRN      16.405        64.50000
# 27                           Bhutan          BTN      18.134        29.90000
# 28                         Botswana          BWA      25.267        15.00000
# 29         Central African Republic          CAF      34.076         3.50000
# ..                              ...          ...         ...             ...
# 165                      Seychelles          SYC      18.600        50.40000
# 166            Syrian Arab Republic          SYR      24.043        26.20000
# 167                            Chad          TCD      45.745         2.30000
# 168                            Togo          TGO      36.080         4.50000
# 169                        Thailand          THA      11.041        28.94000
# 170                      Tajikistan          TJK      30.792        16.00000
# 171                    Turkmenistan          TKM      21.322         9.60000
# 172                     Timor-Leste          TLS      35.755         1.10000
# 173                           Tonga          TON      25.409        35.00000
# 174             Trinidad and Tobago          TTO      14.590        63.80000
# 175                         Tunisia          TUN      19.800        43.80000
# 176                          Turkey          TUR      16.836        46.25000
# 177                        Tanzania          TZA      39.518         4.40000
# 178                          Uganda          UGA      43.474        16.20000
# 179                         Ukraine          UKR      11.100        41.00000
# 180                         Uruguay          URY      14.374        57.69000
# 181                   United States          USA      12.500        84.20000
# 182                      Uzbekistan          UZB      22.500        38.20000
# 183  St. Vincent and the Grenadines          VCT      16.306        52.00000
# 184                   Venezuela, RB          VEN      19.842        54.90000
# 185           Virgin Islands (U.S.)          VIR      10.700        45.30000
# 186                         Vietnam          VNM      15.537        43.90000
# 187                         Vanuatu          VUT      26.739        11.30000
# 188              West Bank and Gaza          PSE      30.394        46.60000
# 189                           Samoa          WSM      26.172        15.30000
# 190                     Yemen, Rep.          YEM      32.947        20.00000
# 191                    South Africa          ZAF      20.850        46.50000
# 192                Congo, Dem. Rep.          COD      42.394         2.20000
# 193                          Zambia          ZMB      40.471        15.40000
# 194                        Zimbabwe          ZWE      35.715        18.50000
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# 5            High income
# 6    Lower middle income
# 7            High income
# 8            High income
# 9            High income
# 10   Upper middle income
# 11            Low income
# 12           High income
# 13            Low income
# 14            Low income
# 15   Lower middle income
# 16   Upper middle income
# 17           High income
# 18           High income
# 19   Upper middle income
# 20   Upper middle income
# 21   Upper middle income
# 22           High income
# 23   Lower middle income
# 24   Upper middle income
# 25           High income
# 26           High income
# 27   Lower middle income
# 28   Upper middle income
# 29            Low income
# ..                   ...
# 165          High income
# 166  Lower middle income
# 167           Low income
# 168           Low income
# 169  Upper middle income
# 170  Lower middle income
# 171  Upper middle income
# 172  Lower middle income
# 173  Upper middle income
# 174          High income
# 175  Upper middle income
# 176  Upper middle income
# 177           Low income
# 178           Low income
# 179  Lower middle income
# 180          High income
# 181          High income
# 182  Lower middle income
# 183  Upper middle income
# 184          High income
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %%
#method 2 change working directory
import os

# %%
print(os.getcwd())
# Out:
# /Users/balajiMacbook/Desktop/Python Course

# %%
#windows:
#os.chdir('C:\\Users\\BAlaji\\')
#Mac:
os.chdir('/Users/balajiMacbook/Desktop')

# %%
print(os.getcwd())
# Out:
# /Users/balajiMacbook/Desktop

# %%
stats2=pd.read_csv('DemographicData.csv')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-13-34f00fe0fd1a> in <module>()
# ----> 1 stats2=pd.read_csv('DemographicData.csv')
#
# /Users/balajiMacbook/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# /Users/balajiMacbook/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# /Users/balajiMacbook/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# /Users/balajiMacbook/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# /Users/balajiMacbook/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# IOError: File DemographicData.csv does not exist

# %%
print(os.getcwd())
# Out:
# /Users/balajiMacbook/Desktop

# %%
os.chdir('/Users/balajiMacbook/Desktop/Python Course')

# %%
print(os.getcwd())
# Out:
# /Users/balajiMacbook/Desktop/Python Course

# %%
stats2=pd.read_csv("DemographicData.csv")

# %%
stats2
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# 11                          Burundi          BDI      44.151         1.30000
# 12                          Belgium          BEL      11.200        82.17020
# 13                            Benin          BEN      36.440         4.90000
# 14                     Burkina Faso          BFA      40.551         9.10000
# 15                       Bangladesh          BGD      20.142         6.63000
# 16                         Bulgaria          BGR       9.200        53.06150
# 17                          Bahrain          BHR      15.040        90.00004
# 18                     Bahamas, The          BHS      15.339        72.00000
# 19           Bosnia and Herzegovina          BIH       9.062        57.79000
# 20                          Belarus          BLR      12.500        54.17000
# 21                           Belize          BLZ      23.092        33.60000
# 22                          Bermuda          BMU      10.400        95.30000
# 23                          Bolivia          BOL      24.236        36.94000
# 24                           Brazil          BRA      14.931        51.04000
# 25                         Barbados          BRB      12.188        73.00000
# 26                Brunei Darussalam          BRN      16.405        64.50000
# 27                           Bhutan          BTN      18.134        29.90000
# 28                         Botswana          BWA      25.267        15.00000
# 29         Central African Republic          CAF      34.076         3.50000
# ..                              ...          ...         ...             ...
# 165                      Seychelles          SYC      18.600        50.40000
# 166            Syrian Arab Republic          SYR      24.043        26.20000
# 167                            Chad          TCD      45.745         2.30000
# 168                            Togo          TGO      36.080         4.50000
# 169                        Thailand          THA      11.041        28.94000
# 170                      Tajikistan          TJK      30.792        16.00000
# 171                    Turkmenistan          TKM      21.322         9.60000
# 172                     Timor-Leste          TLS      35.755         1.10000
# 173                           Tonga          TON      25.409        35.00000
# 174             Trinidad and Tobago          TTO      14.590        63.80000
# 175                         Tunisia          TUN      19.800        43.80000
# 176                          Turkey          TUR      16.836        46.25000
# 177                        Tanzania          TZA      39.518         4.40000
# 178                          Uganda          UGA      43.474        16.20000
# 179                         Ukraine          UKR      11.100        41.00000
# 180                         Uruguay          URY      14.374        57.69000
# 181                   United States          USA      12.500        84.20000
# 182                      Uzbekistan          UZB      22.500        38.20000
# 183  St. Vincent and the Grenadines          VCT      16.306        52.00000
# 184                   Venezuela, RB          VEN      19.842        54.90000
# 185           Virgin Islands (U.S.)          VIR      10.700        45.30000
# 186                         Vietnam          VNM      15.537        43.90000
# 187                         Vanuatu          VUT      26.739        11.30000
# 188              West Bank and Gaza          PSE      30.394        46.60000
# 189                           Samoa          WSM      26.172        15.30000
# 190                     Yemen, Rep.          YEM      32.947        20.00000
# 191                    South Africa          ZAF      20.850        46.50000
# 192                Congo, Dem. Rep.          COD      42.394         2.20000
# 193                          Zambia          ZMB      40.471        15.40000
# 194                        Zimbabwe          ZWE      35.715        18.50000
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# 5            High income
# 6    Lower middle income
# 7            High income
# 8            High income
# 9            High income
# 10   Upper middle income
# 11            Low income
# 12           High income
# 13            Low income
# 14            Low income
# 15   Lower middle income
# 16   Upper middle income
# 17           High income
# 18           High income
# 19   Upper middle income
# 20   Upper middle income
# 21   Upper middle income
# 22           High income
# 23   Lower middle income
# 24   Upper middle income
# 25           High income
# 26           High income
# 27   Lower middle income
# 28   Upper middle income
# 29            Low income
# ..                   ...
# 165          High income
# 166  Lower middle income
# 167           Low income
# 168           Low income
# 169  Upper middle income
# 170  Lower middle income
# 171  Upper middle income
# 172  Lower middle income
# 173  Upper middle income
# 174          High income
# 175  Upper middle income
# 176  Upper middle income
# 177           Low income
# 178           Low income
# 179  Lower middle income
# 180          High income
# 181          High income
# 182  Lower middle income
# 183  Upper middle income
# 184          High income
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %%
####Exploring your data

# %%
stats
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# 11                          Burundi          BDI      44.151         1.30000
# 12                          Belgium          BEL      11.200        82.17020
# 13                            Benin          BEN      36.440         4.90000
# 14                     Burkina Faso          BFA      40.551         9.10000
# 15                       Bangladesh          BGD      20.142         6.63000
# 16                         Bulgaria          BGR       9.200        53.06150
# 17                          Bahrain          BHR      15.040        90.00004
# 18                     Bahamas, The          BHS      15.339        72.00000
# 19           Bosnia and Herzegovina          BIH       9.062        57.79000
# 20                          Belarus          BLR      12.500        54.17000
# 21                           Belize          BLZ      23.092        33.60000
# 22                          Bermuda          BMU      10.400        95.30000
# 23                          Bolivia          BOL      24.236        36.94000
# 24                           Brazil          BRA      14.931        51.04000
# 25                         Barbados          BRB      12.188        73.00000
# 26                Brunei Darussalam          BRN      16.405        64.50000
# 27                           Bhutan          BTN      18.134        29.90000
# 28                         Botswana          BWA      25.267        15.00000
# 29         Central African Republic          CAF      34.076         3.50000
# ..                              ...          ...         ...             ...
# 165                      Seychelles          SYC      18.600        50.40000
# 166            Syrian Arab Republic          SYR      24.043        26.20000
# 167                            Chad          TCD      45.745         2.30000
# 168                            Togo          TGO      36.080         4.50000
# 169                        Thailand          THA      11.041        28.94000
# 170                      Tajikistan          TJK      30.792        16.00000
# 171                    Turkmenistan          TKM      21.322         9.60000
# 172                     Timor-Leste          TLS      35.755         1.10000
# 173                           Tonga          TON      25.409        35.00000
# 174             Trinidad and Tobago          TTO      14.590        63.80000
# 175                         Tunisia          TUN      19.800        43.80000
# 176                          Turkey          TUR      16.836        46.25000
# 177                        Tanzania          TZA      39.518         4.40000
# 178                          Uganda          UGA      43.474        16.20000
# 179                         Ukraine          UKR      11.100        41.00000
# 180                         Uruguay          URY      14.374        57.69000
# 181                   United States          USA      12.500        84.20000
# 182                      Uzbekistan          UZB      22.500        38.20000
# 183  St. Vincent and the Grenadines          VCT      16.306        52.00000
# 184                   Venezuela, RB          VEN      19.842        54.90000
# 185           Virgin Islands (U.S.)          VIR      10.700        45.30000
# 186                         Vietnam          VNM      15.537        43.90000
# 187                         Vanuatu          VUT      26.739        11.30000
# 188              West Bank and Gaza          PSE      30.394        46.60000
# 189                           Samoa          WSM      26.172        15.30000
# 190                     Yemen, Rep.          YEM      32.947        20.00000
# 191                    South Africa          ZAF      20.850        46.50000
# 192                Congo, Dem. Rep.          COD      42.394         2.20000
# 193                          Zambia          ZMB      40.471        15.40000
# 194                        Zimbabwe          ZWE      35.715        18.50000
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# 5            High income
# 6    Lower middle income
# 7            High income
# 8            High income
# 9            High income
# 10   Upper middle income
# 11            Low income
# 12           High income
# 13            Low income
# 14            Low income
# 15   Lower middle income
# 16   Upper middle income
# 17           High income
# 18           High income
# 19   Upper middle income
# 20   Upper middle income
# 21   Upper middle income
# 22           High income
# 23   Lower middle income
# 24   Upper middle income
# 25           High income
# 26           High income
# 27   Lower middle income
# 28   Upper middle income
# 29            Low income
# ..                   ...
# 165          High income
# 166  Lower middle income
# 167           Low income
# 168           Low income
# 169  Upper middle income
# 170  Lower middle income
# 171  Upper middle income
# 172  Lower middle income
# 173  Upper middle income
# 174          High income
# 175  Upper middle income
# 176  Upper middle income
# 177           Low income
# 178           Low income
# 179  Lower middle income
# 180          High income
# 181          High income
# 182  Lower middle income
# 183  Upper middle income
# 184          High income
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %%
#2. Number of rows
len(stats) #195 rows imported
# Out:
# 195

# %%
#3. See columns
stats.columns
# Out:
# Index([u'Country Name', u'Country Code', u'Birth rate', u'Internet users',
#        u'Income Group'],
#       dtype='object')

# %%
# 4. number of columns

# %%
len(stats.columns)
# Out:
# 5

# %%
#5.Top rows
stats.head(10) # remember the brackets
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244         78.9000
# 1           Afghanistan          AFG      35.253          5.9000
# 2                Angola          AGO      45.985         19.1000
# 3               Albania          ALB      12.877         57.2000
# 4  United Arab Emirates          ARE      11.044         88.0000
# 5             Argentina          ARG      17.716         59.9000
# 6               Armenia          ARM      13.308         41.9000
# 7   Antigua and Barbuda          ATG      16.447         63.4000
# 8             Australia          AUS      13.200         83.0000
# 9               Austria          AUT       9.400         80.6188
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
#6. bottom rows
stats.tail(10)
# Out:
#               Country Name Country Code  Birth rate  Internet users  \
# 185  Virgin Islands (U.S.)          VIR      10.700            45.3
# 186                Vietnam          VNM      15.537            43.9
# 187                Vanuatu          VUT      26.739            11.3
# 188     West Bank and Gaza          PSE      30.394            46.6
# 189                  Samoa          WSM      26.172            15.3
# 190            Yemen, Rep.          YEM      32.947            20.0
# 191           South Africa          ZAF      20.850            46.5
# 192       Congo, Dem. Rep.          COD      42.394             2.2
# 193                 Zambia          ZMB      40.471            15.4
# 194               Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
# information on the columns

# %%
stats.info()  #like the str function in R
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# Country Name      195 non-null object
# Country Code      195 non-null object
# Birth rate        195 non-null float64
# Internet users    195 non-null float64
# Income Group      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
#8. get stats on the columns
stats.describe() #like summary() in R
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %%
# Summary
stats
len(stats)
stats.columns
stats.head()
stats.tail()
stats.info()
stats.describe()
stats.describe().transpose()

# %%
# renaming columns of a dataframe

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.columns
# Out:
# Index([u'Country Name', u'Country Code', u'Birth rate', u'Internet users',
#        u'Income Group'],
#       dtype='object')

# %%
stats.columns = ["a","b","c","d","e"]

# %%
stats.head()
# Out:
#                       a    b       c     d                    e
# 0                 Aruba  ABW  10.244  78.9          High income
# 1           Afghanistan  AFG  35.253   5.9           Low income
# 2                Angola  AGO  45.985  19.1  Upper middle income
# 3               Albania  ALB  12.877  57.2  Upper middle income
# 4  United Arab Emirates  ARE  11.044  88.0          High income

# %%
stats.columns=['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',\
       'IncomeGroup']

# %%
stats.columns
# Out:
# Index([u'CountryName', u'CountryCode', u'BirthRate', u'InternetUsers',
#        u'IncomeGroup'],
#       dtype='object')

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#subsetting dataframes in pandas

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# Three parts. Buckle Up!
# - Rows
#- Columns
# - combine two

# %%
# Part 1 . Rows 
stats[2:5]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 0                             Aruba         ABW     10.244       78.90000
# 1                       Afghanistan         AFG     35.253        5.90000
# 2                            Angola         AGO     45.985       19.10000
# 3                           Albania         ALB     12.877       57.20000
# 4              United Arab Emirates         ARE     11.044       88.00000
# 5                         Argentina         ARG     17.716       59.90000
# 6                           Armenia         ARM     13.308       41.90000
# 7               Antigua and Barbuda         ATG     16.447       63.40000
# 8                         Australia         AUS     13.200       83.00000
# 9                           Austria         AUT      9.400       80.61880
# 10                       Azerbaijan         AZE     18.300       58.70000
# 11                          Burundi         BDI     44.151        1.30000
# 12                          Belgium         BEL     11.200       82.17020
# 13                            Benin         BEN     36.440        4.90000
# 14                     Burkina Faso         BFA     40.551        9.10000
# 15                       Bangladesh         BGD     20.142        6.63000
# 16                         Bulgaria         BGR      9.200       53.06150
# 17                          Bahrain         BHR     15.040       90.00004
# 18                     Bahamas, The         BHS     15.339       72.00000
# 19           Bosnia and Herzegovina         BIH      9.062       57.79000
# 20                          Belarus         BLR     12.500       54.17000
# 21                           Belize         BLZ     23.092       33.60000
# 22                          Bermuda         BMU     10.400       95.30000
# 23                          Bolivia         BOL     24.236       36.94000
# 24                           Brazil         BRA     14.931       51.04000
# 25                         Barbados         BRB     12.188       73.00000
# 26                Brunei Darussalam         BRN     16.405       64.50000
# 27                           Bhutan         BTN     18.134       29.90000
# 28                         Botswana         BWA     25.267       15.00000
# 29         Central African Republic         CAF     34.076        3.50000
# ..                              ...         ...        ...            ...
# 165                      Seychelles         SYC     18.600       50.40000
# 166            Syrian Arab Republic         SYR     24.043       26.20000
# 167                            Chad         TCD     45.745        2.30000
# 168                            Togo         TGO     36.080        4.50000
# 169                        Thailand         THA     11.041       28.94000
# 170                      Tajikistan         TJK     30.792       16.00000
# 171                    Turkmenistan         TKM     21.322        9.60000
# 172                     Timor-Leste         TLS     35.755        1.10000
# 173                           Tonga         TON     25.409       35.00000
# 174             Trinidad and Tobago         TTO     14.590       63.80000
# 175                         Tunisia         TUN     19.800       43.80000
# 176                          Turkey         TUR     16.836       46.25000
# 177                        Tanzania         TZA     39.518        4.40000
# 178                          Uganda         UGA     43.474       16.20000
# 179                         Ukraine         UKR     11.100       41.00000
# 180                         Uruguay         URY     14.374       57.69000
# 181                   United States         USA     12.500       84.20000
# 182                      Uzbekistan         UZB     22.500       38.20000
# 183  St. Vincent and the Grenadines         VCT     16.306       52.00000
# 184                   Venezuela, RB         VEN     19.842       54.90000
# 185           Virgin Islands (U.S.)         VIR     10.700       45.30000
# 186                         Vietnam         VNM     15.537       43.90000
# 187                         Vanuatu         VUT     26.739       11.30000
# 188              West Bank and Gaza         PSE     30.394       46.60000
# 189                           Samoa         WSM     26.172       15.30000
# 190                     Yemen, Rep.         YEM     32.947       20.00000
# 191                    South Africa         ZAF     20.850       46.50000
# 192                Congo, Dem. Rep.         COD     42.394        2.20000
# 193                          Zambia         ZMB     40.471       15.40000
# 194                        Zimbabwe         ZWE     35.715       18.50000
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# 5            High income
# 6    Lower middle income
# 7            High income
# 8            High income
# 9            High income
# 10   Upper middle income
# 11            Low income
# 12           High income
# 13            Low income
# 14            Low income
# 15   Lower middle income
# 16   Upper middle income
# 17           High income
# 18           High income
# 19   Upper middle income
# 20   Upper middle income
# 21   Upper middle income
# 22           High income
# 23   Lower middle income
# 24   Upper middle income
# 25           High income
# 26           High income
# 27   Lower middle income
# 28   Upper middle income
# 29            Low income
# ..                   ...
# 165          High income
# 166  Lower middle income
# 167           Low income
# 168           Low income
# 169  Upper middle income
# 170  Lower middle income
# 171  Upper middle income
# 172  Lower middle income
# 173  Upper middle income
# 174          High income
# 175  Upper middle income
# 176  Upper middle income
# 177           Low income
# 178           Low income
# 179  Lower middle income
# 180          High income
# 181          High income
# 182  Lower middle income
# 183  Upper middle income
# 184          High income
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %%
stats[185:]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 185  Virgin Islands (U.S.)         VIR     10.700           45.3
# 186                Vietnam         VNM     15.537           43.9
# 187                Vanuatu         VUT     26.739           11.3
# 188     West Bank and Gaza         PSE     30.394           46.6
# 189                  Samoa         WSM     26.172           15.3
# 190            Yemen, Rep.         YEM     32.947           20.0
# 191           South Africa         ZAF     20.850           46.5
# 192       Congo, Dem. Rep.         COD     42.394            2.2
# 193                 Zambia         ZMB     40.471           15.4
# 194               Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
stats[:10]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
stats.head(10)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
# quick exercise (refresher)

# %%
# reverse the dataframe

# %%
stats[:: -1]
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 194                        Zimbabwe         ZWE     35.715       18.50000
# 193                          Zambia         ZMB     40.471       15.40000
# 192                Congo, Dem. Rep.         COD     42.394        2.20000
# 191                    South Africa         ZAF     20.850       46.50000
# 190                     Yemen, Rep.         YEM     32.947       20.00000
# 189                           Samoa         WSM     26.172       15.30000
# 188              West Bank and Gaza         PSE     30.394       46.60000
# 187                         Vanuatu         VUT     26.739       11.30000
# 186                         Vietnam         VNM     15.537       43.90000
# 185           Virgin Islands (U.S.)         VIR     10.700       45.30000
# 184                   Venezuela, RB         VEN     19.842       54.90000
# 183  St. Vincent and the Grenadines         VCT     16.306       52.00000
# 182                      Uzbekistan         UZB     22.500       38.20000
# 181                   United States         USA     12.500       84.20000
# 180                         Uruguay         URY     14.374       57.69000
# 179                         Ukraine         UKR     11.100       41.00000
# 178                          Uganda         UGA     43.474       16.20000
# 177                        Tanzania         TZA     39.518        4.40000
# 176                          Turkey         TUR     16.836       46.25000
# 175                         Tunisia         TUN     19.800       43.80000
# 174             Trinidad and Tobago         TTO     14.590       63.80000
# 173                           Tonga         TON     25.409       35.00000
# 172                     Timor-Leste         TLS     35.755        1.10000
# 171                    Turkmenistan         TKM     21.322        9.60000
# 170                      Tajikistan         TJK     30.792       16.00000
# 169                        Thailand         THA     11.041       28.94000
# 168                            Togo         TGO     36.080        4.50000
# 167                            Chad         TCD     45.745        2.30000
# 166            Syrian Arab Republic         SYR     24.043       26.20000
# 165                      Seychelles         SYC     18.600       50.40000
# ..                              ...         ...        ...            ...
# 29         Central African Republic         CAF     34.076        3.50000
# 28                         Botswana         BWA     25.267       15.00000
# 27                           Bhutan         BTN     18.134       29.90000
# 26                Brunei Darussalam         BRN     16.405       64.50000
# 25                         Barbados         BRB     12.188       73.00000
# 24                           Brazil         BRA     14.931       51.04000
# 23                          Bolivia         BOL     24.236       36.94000
# 22                          Bermuda         BMU     10.400       95.30000
# 21                           Belize         BLZ     23.092       33.60000
# 20                          Belarus         BLR     12.500       54.17000
# 19           Bosnia and Herzegovina         BIH      9.062       57.79000
# 18                     Bahamas, The         BHS     15.339       72.00000
# 17                          Bahrain         BHR     15.040       90.00004
# 16                         Bulgaria         BGR      9.200       53.06150
# 15                       Bangladesh         BGD     20.142        6.63000
# 14                     Burkina Faso         BFA     40.551        9.10000
# 13                            Benin         BEN     36.440        4.90000
# 12                          Belgium         BEL     11.200       82.17020
# 11                          Burundi         BDI     44.151        1.30000
# 10                       Azerbaijan         AZE     18.300       58.70000
# 9                           Austria         AUT      9.400       80.61880
# 8                         Australia         AUS     13.200       83.00000
# 7               Antigua and Barbuda         ATG     16.447       63.40000
# 6                           Armenia         ARM     13.308       41.90000
# 5                         Argentina         ARG     17.716       59.90000
# 4              United Arab Emirates         ARE     11.044       88.00000
# 3                           Albania         ALB     12.877       57.20000
# 2                            Angola         AGO     45.985       19.10000
# 1                       Afghanistan         AFG     35.253        5.90000
# 0                             Aruba         ABW     10.244       78.90000
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# 189  Lower middle income
# 188  Lower middle income
# 187  Lower middle income
# 186  Lower middle income
# 185          High income
# 184          High income
# 183  Upper middle income
# 182  Lower middle income
# 181          High income
# 180          High income
# 179  Lower middle income
# 178           Low income
# 177           Low income
# 176  Upper middle income
# 175  Upper middle income
# 174          High income
# 173  Upper middle income
# 172  Lower middle income
# 171  Upper middle income
# 170  Lower middle income
# 169  Upper middle income
# 168           Low income
# 167           Low income
# 166  Lower middle income
# 165          High income
# ..                   ...
# 29            Low income
# 28   Upper middle income
# 27   Lower middle income
# 26           High income
# 25           High income
# 24   Upper middle income
# 23   Lower middle income
# 22           High income
# 21   Upper middle income
# 20   Upper middle income
# 19   Upper middle income
# 18           High income
# 17           High income
# 16   Upper middle income
# 15   Lower middle income
# 14            Low income
# 13            Low income
# 12           High income
# 11            Low income
# 10   Upper middle income
# 9            High income
# 8            High income
# 7            High income
# 6    Lower middle income
# 5            High income
# 4            High income
# 3    Upper middle income
# 2    Upper middle income
# 1             Low income
# 0            High income
#
# [195 rows x 5 columns]

# %%
stats
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 0                             Aruba         ABW     10.244       78.90000
# 1                       Afghanistan         AFG     35.253        5.90000
# 2                            Angola         AGO     45.985       19.10000
# 3                           Albania         ALB     12.877       57.20000
# 4              United Arab Emirates         ARE     11.044       88.00000
# 5                         Argentina         ARG     17.716       59.90000
# 6                           Armenia         ARM     13.308       41.90000
# 7               Antigua and Barbuda         ATG     16.447       63.40000
# 8                         Australia         AUS     13.200       83.00000
# 9                           Austria         AUT      9.400       80.61880
# 10                       Azerbaijan         AZE     18.300       58.70000
# 11                          Burundi         BDI     44.151        1.30000
# 12                          Belgium         BEL     11.200       82.17020
# 13                            Benin         BEN     36.440        4.90000
# 14                     Burkina Faso         BFA     40.551        9.10000
# 15                       Bangladesh         BGD     20.142        6.63000
# 16                         Bulgaria         BGR      9.200       53.06150
# 17                          Bahrain         BHR     15.040       90.00004
# 18                     Bahamas, The         BHS     15.339       72.00000
# 19           Bosnia and Herzegovina         BIH      9.062       57.79000
# 20                          Belarus         BLR     12.500       54.17000
# 21                           Belize         BLZ     23.092       33.60000
# 22                          Bermuda         BMU     10.400       95.30000
# 23                          Bolivia         BOL     24.236       36.94000
# 24                           Brazil         BRA     14.931       51.04000
# 25                         Barbados         BRB     12.188       73.00000
# 26                Brunei Darussalam         BRN     16.405       64.50000
# 27                           Bhutan         BTN     18.134       29.90000
# 28                         Botswana         BWA     25.267       15.00000
# 29         Central African Republic         CAF     34.076        3.50000
# ..                              ...         ...        ...            ...
# 165                      Seychelles         SYC     18.600       50.40000
# 166            Syrian Arab Republic         SYR     24.043       26.20000
# 167                            Chad         TCD     45.745        2.30000
# 168                            Togo         TGO     36.080        4.50000
# 169                        Thailand         THA     11.041       28.94000
# 170                      Tajikistan         TJK     30.792       16.00000
# 171                    Turkmenistan         TKM     21.322        9.60000
# 172                     Timor-Leste         TLS     35.755        1.10000
# 173                           Tonga         TON     25.409       35.00000
# 174             Trinidad and Tobago         TTO     14.590       63.80000
# 175                         Tunisia         TUN     19.800       43.80000
# 176                          Turkey         TUR     16.836       46.25000
# 177                        Tanzania         TZA     39.518        4.40000
# 178                          Uganda         UGA     43.474       16.20000
# 179                         Ukraine         UKR     11.100       41.00000
# 180                         Uruguay         URY     14.374       57.69000
# 181                   United States         USA     12.500       84.20000
# 182                      Uzbekistan         UZB     22.500       38.20000
# 183  St. Vincent and the Grenadines         VCT     16.306       52.00000
# 184                   Venezuela, RB         VEN     19.842       54.90000
# 185           Virgin Islands (U.S.)         VIR     10.700       45.30000
# 186                         Vietnam         VNM     15.537       43.90000
# 187                         Vanuatu         VUT     26.739       11.30000
# 188              West Bank and Gaza         PSE     30.394       46.60000
# 189                           Samoa         WSM     26.172       15.30000
# 190                     Yemen, Rep.         YEM     32.947       20.00000
# 191                    South Africa         ZAF     20.850       46.50000
# 192                Congo, Dem. Rep.         COD     42.394        2.20000
# 193                          Zambia         ZMB     40.471       15.40000
# 194                        Zimbabwe         ZWE     35.715       18.50000
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# 5            High income
# 6    Lower middle income
# 7            High income
# 8            High income
# 9            High income
# 10   Upper middle income
# 11            Low income
# 12           High income
# 13            Low income
# 14            Low income
# 15   Lower middle income
# 16   Upper middle income
# 17           High income
# 18           High income
# 19   Upper middle income
# 20   Upper middle income
# 21   Upper middle income
# 22           High income
# 23   Lower middle income
# 24   Upper middle income
# 25           High income
# 26           High income
# 27   Lower middle income
# 28   Upper middle income
# 29            Low income
# ..                   ...
# 165          High income
# 166  Lower middle income
# 167           Low income
# 168           Low income
# 169  Upper middle income
# 170  Lower middle income
# 171  Upper middle income
# 172  Lower middle income
# 173  Upper middle income
# 174          High income
# 175  Upper middle income
# 176  Upper middle income
# 177           Low income
# 178           Low income
# 179  Lower middle income
# 180          High income
# 181          High income
# 182  Lower middle income
# 183  Upper middle income
# 184          High income
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %%
stats
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 0                             Aruba         ABW     10.244       78.90000
# 1                       Afghanistan         AFG     35.253        5.90000
# 2                            Angola         AGO     45.985       19.10000
# 3                           Albania         ALB     12.877       57.20000
# 4              United Arab Emirates         ARE     11.044       88.00000
# 5                         Argentina         ARG     17.716       59.90000
# 6                           Armenia         ARM     13.308       41.90000
# 7               Antigua and Barbuda         ATG     16.447       63.40000
# 8                         Australia         AUS     13.200       83.00000
# 9                           Austria         AUT      9.400       80.61880
# 10                       Azerbaijan         AZE     18.300       58.70000
# 11                          Burundi         BDI     44.151        1.30000
# 12                          Belgium         BEL     11.200       82.17020
# 13                            Benin         BEN     36.440        4.90000
# 14                     Burkina Faso         BFA     40.551        9.10000
# 15                       Bangladesh         BGD     20.142        6.63000
# 16                         Bulgaria         BGR      9.200       53.06150
# 17                          Bahrain         BHR     15.040       90.00004
# 18                     Bahamas, The         BHS     15.339       72.00000
# 19           Bosnia and Herzegovina         BIH      9.062       57.79000
# 20                          Belarus         BLR     12.500       54.17000
# 21                           Belize         BLZ     23.092       33.60000
# 22                          Bermuda         BMU     10.400       95.30000
# 23                          Bolivia         BOL     24.236       36.94000
# 24                           Brazil         BRA     14.931       51.04000
# 25                         Barbados         BRB     12.188       73.00000
# 26                Brunei Darussalam         BRN     16.405       64.50000
# 27                           Bhutan         BTN     18.134       29.90000
# 28                         Botswana         BWA     25.267       15.00000
# 29         Central African Republic         CAF     34.076        3.50000
# ..                              ...         ...        ...            ...
# 165                      Seychelles         SYC     18.600       50.40000
# 166            Syrian Arab Republic         SYR     24.043       26.20000
# 167                            Chad         TCD     45.745        2.30000
# 168                            Togo         TGO     36.080        4.50000
# 169                        Thailand         THA     11.041       28.94000
# 170                      Tajikistan         TJK     30.792       16.00000
# 171                    Turkmenistan         TKM     21.322        9.60000
# 172                     Timor-Leste         TLS     35.755        1.10000
# 173                           Tonga         TON     25.409       35.00000
# 174             Trinidad and Tobago         TTO     14.590       63.80000
# 175                         Tunisia         TUN     19.800       43.80000
# 176                          Turkey         TUR     16.836       46.25000
# 177                        Tanzania         TZA     39.518        4.40000
# 178                          Uganda         UGA     43.474       16.20000
# 179                         Ukraine         UKR     11.100       41.00000
# 180                         Uruguay         URY     14.374       57.69000
# 181                   United States         USA     12.500       84.20000
# 182                      Uzbekistan         UZB     22.500       38.20000
# 183  St. Vincent and the Grenadines         VCT     16.306       52.00000
# 184                   Venezuela, RB         VEN     19.842       54.90000
# 185           Virgin Islands (U.S.)         VIR     10.700       45.30000
# 186                         Vietnam         VNM     15.537       43.90000
# 187                         Vanuatu         VUT     26.739       11.30000
# 188              West Bank and Gaza         PSE     30.394       46.60000
# 189                           Samoa         WSM     26.172       15.30000
# 190                     Yemen, Rep.         YEM     32.947       20.00000
# 191                    South Africa         ZAF     20.850       46.50000
# 192                Congo, Dem. Rep.         COD     42.394        2.20000
# 193                          Zambia         ZMB     40.471       15.40000
# 194                        Zimbabwe         ZWE     35.715       18.50000
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# 5            High income
# 6    Lower middle income
# 7            High income
# 8            High income
# 9            High income
# 10   Upper middle income
# 11            Low income
# 12           High income
# 13            Low income
# 14            Low income
# 15   Lower middle income
# 16   Upper middle income
# 17           High income
# 18           High income
# 19   Upper middle income
# 20   Upper middle income
# 21   Upper middle income
# 22           High income
# 23   Lower middle income
# 24   Upper middle income
# 25           High income
# 26           High income
# 27   Lower middle income
# 28   Upper middle income
# 29            Low income
# ..                   ...
# 165          High income
# 166  Lower middle income
# 167           Low income
# 168           Low income
# 169  Upper middle income
# 170  Lower middle income
# 171  Upper middle income
# 172  Lower middle income
# 173  Upper middle income
# 174          High income
# 175  Upper middle income
# 176  Upper middle income
# 177           Low income
# 178           Low income
# 179  Lower middle income
# 180          High income
# 181          High income
# 182  Lower middle income
# 183  Upper middle income
# 184          High income
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %%
stats[: : -1]
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 194                        Zimbabwe         ZWE     35.715       18.50000
# 193                          Zambia         ZMB     40.471       15.40000
# 192                Congo, Dem. Rep.         COD     42.394        2.20000
# 191                    South Africa         ZAF     20.850       46.50000
# 190                     Yemen, Rep.         YEM     32.947       20.00000
# 189                           Samoa         WSM     26.172       15.30000
# 188              West Bank and Gaza         PSE     30.394       46.60000
# 187                         Vanuatu         VUT     26.739       11.30000
# 186                         Vietnam         VNM     15.537       43.90000
# 185           Virgin Islands (U.S.)         VIR     10.700       45.30000
# 184                   Venezuela, RB         VEN     19.842       54.90000
# 183  St. Vincent and the Grenadines         VCT     16.306       52.00000
# 182                      Uzbekistan         UZB     22.500       38.20000
# 181                   United States         USA     12.500       84.20000
# 180                         Uruguay         URY     14.374       57.69000
# 179                         Ukraine         UKR     11.100       41.00000
# 178                          Uganda         UGA     43.474       16.20000
# 177                        Tanzania         TZA     39.518        4.40000
# 176                          Turkey         TUR     16.836       46.25000
# 175                         Tunisia         TUN     19.800       43.80000
# 174             Trinidad and Tobago         TTO     14.590       63.80000
# 173                           Tonga         TON     25.409       35.00000
# 172                     Timor-Leste         TLS     35.755        1.10000
# 171                    Turkmenistan         TKM     21.322        9.60000
# 170                      Tajikistan         TJK     30.792       16.00000
# 169                        Thailand         THA     11.041       28.94000
# 168                            Togo         TGO     36.080        4.50000
# 167                            Chad         TCD     45.745        2.30000
# 166            Syrian Arab Republic         SYR     24.043       26.20000
# 165                      Seychelles         SYC     18.600       50.40000
# ..                              ...         ...        ...            ...
# 29         Central African Republic         CAF     34.076        3.50000
# 28                         Botswana         BWA     25.267       15.00000
# 27                           Bhutan         BTN     18.134       29.90000
# 26                Brunei Darussalam         BRN     16.405       64.50000
# 25                         Barbados         BRB     12.188       73.00000
# 24                           Brazil         BRA     14.931       51.04000
# 23                          Bolivia         BOL     24.236       36.94000
# 22                          Bermuda         BMU     10.400       95.30000
# 21                           Belize         BLZ     23.092       33.60000
# 20                          Belarus         BLR     12.500       54.17000
# 19           Bosnia and Herzegovina         BIH      9.062       57.79000
# 18                     Bahamas, The         BHS     15.339       72.00000
# 17                          Bahrain         BHR     15.040       90.00004
# 16                         Bulgaria         BGR      9.200       53.06150
# 15                       Bangladesh         BGD     20.142        6.63000
# 14                     Burkina Faso         BFA     40.551        9.10000
# 13                            Benin         BEN     36.440        4.90000
# 12                          Belgium         BEL     11.200       82.17020
# 11                          Burundi         BDI     44.151        1.30000
# 10                       Azerbaijan         AZE     18.300       58.70000
# 9                           Austria         AUT      9.400       80.61880
# 8                         Australia         AUS     13.200       83.00000
# 7               Antigua and Barbuda         ATG     16.447       63.40000
# 6                           Armenia         ARM     13.308       41.90000
# 5                         Argentina         ARG     17.716       59.90000
# 4              United Arab Emirates         ARE     11.044       88.00000
# 3                           Albania         ALB     12.877       57.20000
# 2                            Angola         AGO     45.985       19.10000
# 1                       Afghanistan         AFG     35.253        5.90000
# 0                             Aruba         ABW     10.244       78.90000
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# 189  Lower middle income
# 188  Lower middle income
# 187  Lower middle income
# 186  Lower middle income
# 185          High income
# 184          High income
# 183  Upper middle income
# 182  Lower middle income
# 181          High income
# 180          High income
# 179  Lower middle income
# 178           Low income
# 177           Low income
# 176  Upper middle income
# 175  Upper middle income
# 174          High income
# 173  Upper middle income
# 172  Lower middle income
# 171  Upper middle income
# 170  Lower middle income
# 169  Upper middle income
# 168           Low income
# 167           Low income
# 166  Lower middle income
# 165          High income
# ..                   ...
# 29            Low income
# 28   Upper middle income
# 27   Lower middle income
# 26           High income
# 25           High income
# 24   Upper middle income
# 23   Lower middle income
# 22           High income
# 21   Upper middle income
# 20   Upper middle income
# 19   Upper middle income
# 18           High income
# 17           High income
# 16   Upper middle income
# 15   Lower middle income
# 14            Low income
# 13            Low income
# 12           High income
# 11            Low income
# 10   Upper middle income
# 9            High income
# 8            High income
# 7            High income
# 6    Lower middle income
# 5            High income
# 4            High income
# 3    Upper middle income
# 2    Upper middle income
# 1             Low income
# 0            High income
#
# [195 rows x 5 columns]

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.tail()
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
len(stats)
# Out:
# 195

# %%
stats.columns
# Out:
# Index([u'CountryName', u'CountryCode', u'BirthRate', u'InternetUsers',
#        u'IncomeGroup'],
#       dtype='object')

# %%
stats[3:6]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
#
#            IncomeGroup
# 3  Upper middle income
# 4          High income
# 5          High income

# %%
# Get only every 20th row

# %%
stats[: : 20]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0         Aruba         ABW     10.244        78.9000          High income
# 20      Belarus         BLR     12.500        54.1700  Upper middle income
# 40   Costa Rica         CRI     15.022        45.9600  Upper middle income
# 60        Gabon         GAB     30.555         9.2000  Upper middle income
# 80        India         IND     20.291        15.1000  Lower middle income
# 100       Libya         LBY     21.425        16.5000  Upper middle income
# 120  Mozambique         MOZ     39.705         5.4000           Low income
# 140      Poland         POL      9.600        62.8492          High income
# 160    Suriname         SUR     18.455        37.4000  Upper middle income
# 180     Uruguay         URY     14.374        57.6900          High income

# %%
# part 2 Columns

# %%
stats.columns
# Out:
# Index([u'CountryName', u'CountryCode', u'BirthRate', u'InternetUsers',
#        u'IncomeGroup'],
#       dtype='object')

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats['CountryName'].head()
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: CountryName, dtype: object

# %%
stats[['CountryName','BirthRate']].head()
# Out:
#             CountryName  BirthRate
# 0                 Aruba     10.244
# 1           Afghanistan     35.253
# 2                Angola     45.985
# 3               Albania     12.877
# 4  United Arab Emirates     11.044

# %%
stats[['BirthRate','CountryName']].head()
# Out:
#    BirthRate           CountryName
# 0     10.244                 Aruba
# 1     35.253           Afghanistan
# 2     45.985                Angola
# 3     12.877               Albania
# 4     11.044  United Arab Emirates

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.BirthRate.head()
# Out:
# 0    10.244
# 1    35.253
# 2    45.985
# 3    12.877
# 4    11.044
# Name: BirthRate, dtype: float64

# %%
# Part 3. combining the two

# %%
stats[4:8][['CountryName','BirthRate']]
# Out:
#             CountryName  BirthRate
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716
# 6               Armenia     13.308
# 7   Antigua and Barbuda     16.447

# %%
#### Basic operations with data frames

# %%
# Already spoke about subsetting

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats[5:10]
# Out:
#            CountryName CountryCode  BirthRate  InternetUsers  \
# 5            Argentina         ARG     17.716        59.9000
# 6              Armenia         ARM     13.308        41.9000
# 7  Antigua and Barbuda         ATG     16.447        63.4000
# 8            Australia         AUS     13.200        83.0000
# 9              Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
stats[['CountryName','BirthRate','InternetUsers']].head()
# Out:
#             CountryName  BirthRate  InternetUsers
# 0                 Aruba     10.244           78.9
# 1           Afghanistan     35.253            5.9
# 2                Angola     45.985           19.1
# 3               Albania     12.877           57.2
# 4  United Arab Emirates     11.044           88.0

# %%
#Mathematical operations
result=stats.BirthRate*stats.InternetUsers

# %%
result.head()
# Out:
# 0    808.2516
# 1    207.9927
# 2    878.3135
# 3    736.5644
# 4    971.8720
# dtype: float64

# %%
#Add column

# %%
stats['MyCalc']=stats.BirthRate*stats.InternetUsers

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    MyCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
#comparison to R
#no recycling option as R is vectorized programming

# %%
# removing a column

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    MyCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
stats.drop('MyCalc',1)
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 0                             Aruba         ABW     10.244       78.90000
# 1                       Afghanistan         AFG     35.253        5.90000
# 2                            Angola         AGO     45.985       19.10000
# 3                           Albania         ALB     12.877       57.20000
# 4              United Arab Emirates         ARE     11.044       88.00000
# 5                         Argentina         ARG     17.716       59.90000
# 6                           Armenia         ARM     13.308       41.90000
# 7               Antigua and Barbuda         ATG     16.447       63.40000
# 8                         Australia         AUS     13.200       83.00000
# 9                           Austria         AUT      9.400       80.61880
# 10                       Azerbaijan         AZE     18.300       58.70000
# 11                          Burundi         BDI     44.151        1.30000
# 12                          Belgium         BEL     11.200       82.17020
# 13                            Benin         BEN     36.440        4.90000
# 14                     Burkina Faso         BFA     40.551        9.10000
# 15                       Bangladesh         BGD     20.142        6.63000
# 16                         Bulgaria         BGR      9.200       53.06150
# 17                          Bahrain         BHR     15.040       90.00004
# 18                     Bahamas, The         BHS     15.339       72.00000
# 19           Bosnia and Herzegovina         BIH      9.062       57.79000
# 20                          Belarus         BLR     12.500       54.17000
# 21                           Belize         BLZ     23.092       33.60000
# 22                          Bermuda         BMU     10.400       95.30000
# 23                          Bolivia         BOL     24.236       36.94000
# 24                           Brazil         BRA     14.931       51.04000
# 25                         Barbados         BRB     12.188       73.00000
# 26                Brunei Darussalam         BRN     16.405       64.50000
# 27                           Bhutan         BTN     18.134       29.90000
# 28                         Botswana         BWA     25.267       15.00000
# 29         Central African Republic         CAF     34.076        3.50000
# ..                              ...         ...        ...            ...
# 165                      Seychelles         SYC     18.600       50.40000
# 166            Syrian Arab Republic         SYR     24.043       26.20000
# 167                            Chad         TCD     45.745        2.30000
# 168                            Togo         TGO     36.080        4.50000
# 169                        Thailand         THA     11.041       28.94000
# 170                      Tajikistan         TJK     30.792       16.00000
# 171                    Turkmenistan         TKM     21.322        9.60000
# 172                     Timor-Leste         TLS     35.755        1.10000
# 173                           Tonga         TON     25.409       35.00000
# 174             Trinidad and Tobago         TTO     14.590       63.80000
# 175                         Tunisia         TUN     19.800       43.80000
# 176                          Turkey         TUR     16.836       46.25000
# 177                        Tanzania         TZA     39.518        4.40000
# 178                          Uganda         UGA     43.474       16.20000
# 179                         Ukraine         UKR     11.100       41.00000
# 180                         Uruguay         URY     14.374       57.69000
# 181                   United States         USA     12.500       84.20000
# 182                      Uzbekistan         UZB     22.500       38.20000
# 183  St. Vincent and the Grenadines         VCT     16.306       52.00000
# 184                   Venezuela, RB         VEN     19.842       54.90000
# 185           Virgin Islands (U.S.)         VIR     10.700       45.30000
# 186                         Vietnam         VNM     15.537       43.90000
# 187                         Vanuatu         VUT     26.739       11.30000
# 188              West Bank and Gaza         PSE     30.394       46.60000
# 189                           Samoa         WSM     26.172       15.30000
# 190                     Yemen, Rep.         YEM     32.947       20.00000
# 191                    South Africa         ZAF     20.850       46.50000
# 192                Congo, Dem. Rep.         COD     42.394        2.20000
# 193                          Zambia         ZMB     40.471       15.40000
# 194                        Zimbabwe         ZWE     35.715       18.50000
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# 5            High income
# 6    Lower middle income
# 7            High income
# 8            High income
# 9            High income
# 10   Upper middle income
# 11            Low income
# 12           High income
# 13            Low income
# 14            Low income
# 15   Lower middle income
# 16   Upper middle income
# 17           High income
# 18           High income
# 19   Upper middle income
# 20   Upper middle income
# 21   Upper middle income
# 22           High income
# 23   Lower middle income
# 24   Upper middle income
# 25           High income
# 26           High income
# 27   Lower middle income
# 28   Upper middle income
# 29            Low income
# ..                   ...
# 165          High income
# 166  Lower middle income
# 167           Low income
# 168           Low income
# 169  Upper middle income
# 170  Lower middle income
# 171  Upper middle income
# 172  Lower middle income
# 173  Upper middle income
# 174          High income
# 175  Upper middle income
# 176  Upper middle income
# 177           Low income
# 178           Low income
# 179  Lower middle income
# 180          High income
# 181          High income
# 182  Lower middle income
# 183  Upper middle income
# 184          High income
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    MyCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
stats=stats.drop('MyCalc',1)

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#Filtering Data Frames

# %%
#Filtering is about Rows

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.InternetUsers<2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170    False
# 171    False
# 172     True
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
stats.InternetUsers[11]
# Out:
# 1.3

# %%
Filter=stats.InternetUsers<2

# %%
Filter
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170    False
# 171    False
# 172     True
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
stats[3:7]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
# 6               Armenia         ARM     13.308           41.9
#
#            IncomeGroup
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income

# %%
stats[30:130 : 20]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 30       Canada         CAN     10.900      85.800000          High income
# 50      Ecuador         ECU     21.070      40.353684  Upper middle income
# 70    Greenland         GRL     14.500      65.800000          High income
# 90   Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 110     Moldova         MDA     12.141      45.000000  Lower middle income

# %%
stats[Filter]
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income

# %%
stats[180:186][['CountryName','InternetUsers']]
# Out:
#                         CountryName  InternetUsers
# 180                         Uruguay          57.69
# 181                   United States          84.20
# 182                      Uzbekistan          38.20
# 183  St. Vincent and the Grenadines          52.00
# 184                   Venezuela, RB          54.90
# 185           Virgin Islands (U.S.)          45.30

# %%
Filter1=stats.BirthRate>40

# %%
stats[stats.BirthRate>40]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# 128  Lower middle income
# 156           Low income
# 167           Low income
# 178           Low income
# 192           Low income
# 193  Lower middle income

# %%
#Even more interesting

# %%
stats.BirthRate>40 and stats.Internet.Users<2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-152-7ad25753552d> in <module>()
# ----> 1 stats.BirthRate>40 and stats.Internet.Users<2
#
# /Users/balajiMacbook/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __nonzero__(self)
#    1571         raise ValueError("The truth value of a {0} is ambiguous. "
#    1572                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1573                          .format(self.__class__.__name__))
#    1574
#    1575     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
stats[(stats.BirthRate>40) & (stats.InternetUsers<2)]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11      Burundi         BDI     44.151            1.3  Low income
# 127       Niger         NER     49.661            1.7  Low income
# 156     Somalia         SOM     43.891            1.5  Low income

# %%
stats[Filter&Filter1]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11      Burundi         BDI     44.151            1.3  Low income
# 127       Niger         NER     49.661            1.7  Low income
# 156     Somalia         SOM     43.891            1.5  Low income

# %%
#another one:
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats[stats.IncomeGroup=="High income"]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0                    Aruba         ABW     10.244       78.90000  High income
# 4     United Arab Emirates         ARE     11.044       88.00000  High income
# 5                Argentina         ARG     17.716       59.90000  High income
# 7      Antigua and Barbuda         ATG     16.447       63.40000  High income
# 8                Australia         AUS     13.200       83.00000  High income
# 9                  Austria         AUT      9.400       80.61880  High income
# 12                 Belgium         BEL     11.200       82.17020  High income
# 17                 Bahrain         BHR     15.040       90.00004  High income
# 18            Bahamas, The         BHS     15.339       72.00000  High income
# 22                 Bermuda         BMU     10.400       95.30000  High income
# 25                Barbados         BRB     12.188       73.00000  High income
# 26       Brunei Darussalam         BRN     16.405       64.50000  High income
# 30                  Canada         CAN     10.900       85.80000  High income
# 31             Switzerland         CHE     10.200       86.34000  High income
# 32                   Chile         CHL     13.385       66.50000  High income
# 42          Cayman Islands         CYM     12.500       74.10000  High income
# 43                  Cyprus         CYP     11.436       65.45480  High income
# 44          Czech Republic         CZE     10.200       74.11040  High income
# 45                 Germany         DEU      8.500       84.17000  High income
# 47                 Denmark         DNK     10.000       94.62970  High income
# 53                   Spain         ESP      9.100       71.63500  High income
# 54                 Estonia         EST     10.300       79.40000  High income
# 56                 Finland         FIN     10.700       91.51440  High income
# 58                  France         FRA     12.300       81.91980  High income
# 61          United Kingdom         GBR     12.200       89.84410  High income
# 67       Equatorial Guinea         GNQ     35.362       16.40000  High income
# 68                  Greece         GRC      8.500       59.86630  High income
# 70               Greenland         GRL     14.500       65.80000  High income
# 72                    Guam         GUM     17.389       65.40000  High income
# 74    Hong Kong SAR, China         HKG      7.900       74.20000  High income
# ..                     ...         ...        ...            ...          ...
# 95             Korea, Rep.         KOR      8.600       84.77000  High income
# 96                  Kuwait         KWT     20.575       75.46000  High income
# 102          Liechtenstein         LIE      9.200       93.80000  High income
# 105              Lithuania         LTU     10.100       68.45290  High income
# 106             Luxembourg         LUX     11.300       93.77650  High income
# 107                 Latvia         LVA     10.200       75.23440  High income
# 108       Macao SAR, China         MAC     11.256       65.80000  High income
# 116                  Malta         MLT      9.500       68.91380  High income
# 126          New Caledonia         NCL     17.000       66.00000  High income
# 130            Netherlands         NLD     10.200       93.95640  High income
# 131                 Norway         NOR     11.600       95.05340  High income
# 133            New Zealand         NZL     13.120       82.78000  High income
# 134                   Oman         OMN     20.419       66.45000  High income
# 140                 Poland         POL      9.600       62.84920  High income
# 141            Puerto Rico         PRI     10.800       73.90000  High income
# 142               Portugal         PRT      7.900       62.09560  High income
# 144       French Polynesia         PYF     16.393       56.80000  High income
# 145                  Qatar         QAT     11.940       85.30000  High income
# 147     Russian Federation         RUS     13.200       67.97000  High income
# 149           Saudi Arabia         SAU     20.576       60.50000  High income
# 152              Singapore         SGP      9.300       81.00000  High income
# 161        Slovak Republic         SVK     10.100       77.88260  High income
# 162               Slovenia         SVN     10.200       72.67560  High income
# 163                 Sweden         SWE     11.800       94.78360  High income
# 165             Seychelles         SYC     18.600       50.40000  High income
# 174    Trinidad and Tobago         TTO     14.590       63.80000  High income
# 180                Uruguay         URY     14.374       57.69000  High income
# 181          United States         USA     12.500       84.20000  High income
# 184          Venezuela, RB         VEN     19.842       54.90000  High income
# 185  Virgin Islands (U.S.)         VIR     10.700       45.30000  High income
#
# [67 rows x 5 columns]

# %%
#How to get unique categories
stats.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
#quick exercise 
# find out everything about malta
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats[stats['CountryName']=='Malta']
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 116       Malta         MLT        9.5        68.9138  High income

# %%
stats[stats['CountryName']=='India']
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 80       India         IND     20.291           15.1  Lower middle income

# %%
### Accesing individual elements

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
##.at  # for labels. Important:Even integers are treated as labels
##.iat # for integer location

# %%
stats.iat[3,4]
# Out:
# 'Upper middle income'

# %%
stats.iat[0,1]
# Out:
# 'ABW'

# %%
stats.at[2,'BirthRate']
# Out:
# 45.985

# %%
stats.at[4,'InternetUsers']
# Out:
# 88.0

# %%
sub10=stats[: : 10]

# %%
sub10
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0          Aruba         ABW     10.244      78.900000          High income
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# 110      Moldova         MDA     12.141      45.000000  Lower middle income
# 120   Mozambique         MOZ     39.705       5.400000           Low income
# 130  Netherlands         NLD     10.200      93.956400          High income
# 140       Poland         POL      9.600      62.849200          High income
# 150        Sudan         SDN     33.477      22.700000  Lower middle income
# 160     Suriname         SUR     18.455      37.400000  Upper middle income
# 170   Tajikistan         TJK     30.792      16.000000  Lower middle income
# 180      Uruguay         URY     14.374      57.690000          High income
# 190  Yemen, Rep.         YEM     32.947      20.000000  Lower middle income

# %%
sub10.iat[10,0]
# Out:
# 'Libya'

# %%
sub10.at[10,'CountryName']
# Out:
# 'Azerbaijan'

# %%
# Introduction to Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize']=8,4
import warnings
warnings.filterwarnings('ignore')

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#Distribution:
Vis1=sns.distplot(stats["InternetUsers"])

# %%
Vis1=sns.distplot(stats["InternetUsers"],bins=30)

# %%
vis2=sns.boxplot(data=stats,x='IncomeGroup',y='BirthRate')

# %%
#seaborn gallery

# %%
vis3=sns.lmplot(data=stats,x='InternetUsers',y='BirthRate',fit_reg=False)

# %%
vis3=sns.lmplot(data=stats,x='InternetUsers',y='BirthRate',fit_reg=False \
        ,hue='IncomeGroup',size=10,aspect=2)

# %%
#keywords Arguments in Python (advaned tutorial)

# %%
#marker size
vis3=sns.lmplot(data=stats,x='InternetUsers',y='BirthRate',fit_reg=False \
        ,hue='IncomeGroup',size=10, \
                scatter_kws={"s":200})

# %%
import matplotlib.pyplot as plt
